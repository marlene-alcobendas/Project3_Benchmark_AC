# %%
import pandas as pd

#import all files
df1 = pd.read_csv("North_America_Airbus.csv") 
df2 = pd.read_csv("North_America_Boeing_CFM.csv")
df3 = pd.read_csv("North_America_Boeing_Rest.csv")
df4 = pd.read_csv("EasternEU_Airbus.csv")
df5 = pd.read_csv("EasternEU_Boeing.csv")
df6 = pd.read_csv("West_EU_Airbus.csv")
df7 = pd.read_csv("West_EU_Boeing.csv")
df8 = pd.read_csv("Latin_Airbus.csv")
df9 = pd.read_csv("Latin_Boeing.csv")


#combine all dataframes into one
df_aw = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9], ignore_index=True)

df_aw.head()
# Out:
#   Aircraft Manufacturer Aircraft Type Aircraft Model Variant  \
# 0                Airbus      A320-200                    200
# 1                Airbus      A320-200                    200
# 2                Airbus      A319-100                    100
# 3                Airbus      A320-200                    200
# 4                Airbus      A320-200                    200
#
#   Aircraft Variant Detail Engine Manufacturer Engine Type  \
# 0                     212                 CFM       CFM56
# 1                     214                 CFM       CFM56
# 2                     112                 CFM       CFM56
# 3                     214                 CFM       CFM56
# 4                     214                 CFM       CFM56
#
#   Engine Model Variant Engine Variant Detail APU Full Name  \
# 0                   5A                   5A3             -
# 1                   5B                 5B4/P             -
# 2                   5B                 5B6/P             -
# 3                   5B                 5B4/P             -
# 4                   5B                 5B4/P             -
#
#   Aircraft Registration Number  ...                   Operator Phone  \
# 0                       N364NW  ...                     404-715-2600
# 1                       C-FGJI  ...  888-247-2262 (Customer Service)
# 2                       N302NV  ...                     702-851-7300
# 3                       N297NV  ...                     702-851-7300
# 4                       N283NV  ...                     702-851-7300
#
#                        Operator Email               Registered Owner/Manager  \
# 0                                   -                        DELTA AIR LINES
# 1                                   -                AERGEN AVIATION FINANCE
# 2  customerrelations@allegiantair.com  SUNRISE ASSET MANAGEMENT LLC [NV-USA]
# 3  customerrelations@allegiantair.com                 BANK OF UTAH [TRUSTEE]
# 4  customerrelations@allegiantair.com  SUNRISE ASSET MANAGEMENT LLC [NV-USA]
#
#   In Service On Order Stored  Hours Cycles Age (Since Delivery)  \
# 0        1.0      NaN    NaN  75833  35997                 26.8
# 1        1.0      NaN    NaN  70865  27058                 23.6
# 2        1.0      NaN    NaN  51115  31015                 20.8
# 3        1.0      NaN    NaN  55338  18967                 19.6
# 4        1.0      NaN    NaN  53381  21646                 19.2
#
#   Number of Engines for Operators
# 0                               2
# 1                               2
# 2                               2
# 3                               2
# 4                               2
#
# [5 rows x 27 columns]

# %%
df_aw.columns

#Review column required within the exported files
df_aw = df_aw[['Aircraft Manufacturer', 'Aircraft Type', 'Aircraft Model Variant', 'Engine Manufacturer', 'Engine Type','Engine Model Variant',
       'Aircraft Registration Number','Aircraft Status', 'Aircraft Delivery Date','Operator', 'Hours','Cycles', 'Age (Since Delivery)', 'Number of Engines for Operators']]

df_aw.head()
# Out:
#   Aircraft Manufacturer Aircraft Type Aircraft Model Variant  \
# 0                Airbus      A320-200                    200
# 1                Airbus      A320-200                    200
# 2                Airbus      A319-100                    100
# 3                Airbus      A320-200                    200
# 4                Airbus      A320-200                    200
#
#   Engine Manufacturer Engine Type Engine Model Variant  \
# 0                 CFM       CFM56                   5A
# 1                 CFM       CFM56                   5B
# 2                 CFM       CFM56                   5B
# 3                 CFM       CFM56                   5B
# 4                 CFM       CFM56                   5B
#
#   Aircraft Registration Number Aircraft Status Aircraft Delivery Date  \
# 0                       N364NW      In Service             03/04/1999
# 1                       C-FGJI      In Service             06/06/2002
# 2                       N302NV      In Service             02/07/2005
# 3                       N297NV      In Service             05/30/2006
# 4                       N283NV      In Service             10/30/2006
#
#                 Operator  Hours  Cycles  Age (Since Delivery)  \
# 0  Delta Air Lines, Inc.  75833   35997                  26.8
# 1             Air Canada  70865   27058                  23.6
# 2          Allegiant Air  51115   31015                  20.8
# 3          Allegiant Air  55338   18967                  19.6
# 4          Allegiant Air  53381   21646                  19.2
#
#    Number of Engines for Operators
# 0                                2
# 1                                2
# 2                                2
# 3                                2
# 4                                2

# %%
#filter the aircraft status to In Service
df_aw = df_aw[df_aw['Aircraft Status'] == 'In Service']

df_aw.head()
# Out:
#   Aircraft Manufacturer Aircraft Type Aircraft Model Variant  \
# 0                Airbus      A320-200                    200
# 1                Airbus      A320-200                    200
# 2                Airbus      A319-100                    100
# 3                Airbus      A320-200                    200
# 4                Airbus      A320-200                    200
#
#   Engine Manufacturer Engine Type Engine Model Variant  \
# 0                 CFM       CFM56                   5A
# 1                 CFM       CFM56                   5B
# 2                 CFM       CFM56                   5B
# 3                 CFM       CFM56                   5B
# 4                 CFM       CFM56                   5B
#
#   Aircraft Registration Number Aircraft Status Aircraft Delivery Date  \
# 0                       N364NW      In Service             03/04/1999
# 1                       C-FGJI      In Service             06/06/2002
# 2                       N302NV      In Service             02/07/2005
# 3                       N297NV      In Service             05/30/2006
# 4                       N283NV      In Service             10/30/2006
#
#                 Operator  Hours  Cycles  Age (Since Delivery)  \
# 0  Delta Air Lines, Inc.  75833   35997                  26.8
# 1             Air Canada  70865   27058                  23.6
# 2          Allegiant Air  51115   31015                  20.8
# 3          Allegiant Air  55338   18967                  19.6
# 4          Allegiant Air  53381   21646                  19.2
#
#    Number of Engines for Operators
# 0                                2
# 1                                2
# 2                                2
# 3                                2
# 4                                2

# %%
#Extract AC type from Aircraft Type column, where aircraft manufacturer is Airbus left 4 digits in aircraft type and boeing left 3 digits
df_aw['AC Type'] = df_aw.apply(lambda row: row['Aircraft Type'][:4] if 'Airbus' in row['Aircraft Manufacturer'] else row['Aircraft Type'][:3], axis=1)

df_aw.head()
# Out:
#   Aircraft Manufacturer Aircraft Type Aircraft Model Variant  \
# 0                Airbus      A320-200                    200
# 1                Airbus      A320-200                    200
# 2                Airbus      A319-100                    100
# 3                Airbus      A320-200                    200
# 4                Airbus      A320-200                    200
#
#   Engine Manufacturer Engine Type Engine Model Variant  \
# 0                 CFM       CFM56                   5A
# 1                 CFM       CFM56                   5B
# 2                 CFM       CFM56                   5B
# 3                 CFM       CFM56                   5B
# 4                 CFM       CFM56                   5B
#
#   Aircraft Registration Number Aircraft Status Aircraft Delivery Date  \
# 0                       N364NW      In Service             03/04/1999
# 1                       C-FGJI      In Service             06/06/2002
# 2                       N302NV      In Service             02/07/2005
# 3                       N297NV      In Service             05/30/2006
# 4                       N283NV      In Service             10/30/2006
#
#                 Operator  Hours  Cycles  Age (Since Delivery)  \
# 0  Delta Air Lines, Inc.  75833   35997                  26.8
# 1             Air Canada  70865   27058                  23.6
# 2          Allegiant Air  51115   31015                  20.8
# 3          Allegiant Air  55338   18967                  19.6
# 4          Allegiant Air  53381   21646                  19.2
#
#    Number of Engines for Operators AC Type
# 0                                2    A320
# 1                                2    A320
# 2                                2    A319
# 3                                2    A320
# 4                                2    A320

# %%
#Review unique values for AC Type
df_aw['AC Type'].unique()
# Out:
# array(['A320', 'A319', 'A321', 'A330', 'A300', 'A220', 'A350', '737',
#        '707', '727', '767', '757', '747', '777', 'MD-', '717', '787',
#        'A340', 'A380', 'A310'], dtype=object)

# %%
#Exclude values "MD-" from column AC type
df_aw = df_aw[~df_aw['AC Type'].str.startswith('MD-', na=False)]

df_aw['AC Type'].unique()
# Out:
# array(['A320', 'A319', 'A321', 'A330', 'A300', 'A220', 'A350', '737',
#        '707', '727', '767', '757', '747', '777', '717', '787', 'A340',
#        'A380', 'A310'], dtype=object)

# %%
#Reorder columns
df_aw = df_aw[['Aircraft Manufacturer', 'AC Type', 'Aircraft Model Variant', 'Engine Manufacturer', 'Engine Type','Engine Model Variant',
       'Aircraft Registration Number','Aircraft Status', 'Aircraft Delivery Date','Operator', 'Hours','Cycles', 'Age (Since Delivery)', 'Number of Engines for Operators']]

df_aw
# Out:
#       Aircraft Manufacturer AC Type Aircraft Model Variant  \
# 0                    Airbus    A320                    200
# 1                    Airbus    A320                    200
# 2                    Airbus    A319                    100
# 3                    Airbus    A320                    200
# 4                    Airbus    A320                    200
# ...                     ...     ...                    ...
# 19462                Boeing     737                  Max 8
# 19463                Boeing     737                  Max 8
# 19464                Boeing     737                  Max 9
# 19465                Boeing     737                  Max 8
# 19466                Boeing     737                  Max 8
#
#       Engine Manufacturer Engine Type Engine Model Variant  \
# 0                     CFM       CFM56                   5A
# 1                     CFM       CFM56                   5B
# 2                     CFM       CFM56                   5B
# 3                     CFM       CFM56                   5B
# 4                     CFM       CFM56                   5B
# ...                   ...         ...                  ...
# 19462                 CFM        LEAP                   1B
# 19463                 CFM        LEAP                   1B
# 19464                 CFM        LEAP                   1B
# 19465                 CFM        LEAP                   1B
# 19466                 CFM        LEAP                   1B
#
#       Aircraft Registration Number Aircraft Status Aircraft Delivery Date  \
# 0                           N364NW      In Service             03/04/1999
# 1                           C-FGJI      In Service             06/06/2002
# 2                           N302NV      In Service             02/07/2005
# 3                           N297NV      In Service             05/30/2006
# 4                           N283NV      In Service             10/30/2006
# ...                            ...             ...                    ...
# 19462                   HP-9809CMP      In Service             09/16/2025
# 19463                   HP-9812CMP      In Service             09/25/2025
# 19464                       N959AM      In Service             09/30/2025
# 19465                   HP-9811CMP      In Service             09/30/2025
# 19466                       XA-AMH      In Service             10/15/2025
#
#                     Operator  Hours  Cycles  Age (Since Delivery)  \
# 0      Delta Air Lines, Inc.  75833   35997                  26.8
# 1                 Air Canada  70865   27058                  23.6
# 2              Allegiant Air  51115   31015                  20.8
# 3              Allegiant Air  55338   18967                  19.6
# 4              Allegiant Air  53381   21646                  19.2
# ...                      ...    ...     ...                   ...
# 19462          Copa Airlines      0       0                   0.3
# 19463          Copa Airlines      0       0                   0.2
# 19464             Aeromexico      0       0                   0.3
# 19465          Copa Airlines      0       0                   0.3
# 19466             Aeromexico      0       0                   0.5
#
#        Number of Engines for Operators
# 0                                    2
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    2
# ...                                ...
# 19462                                2
# 19463                                2
# 19464                                2
# 19465                                2
# 19466                                2
#
# [12973 rows x 14 columns]
